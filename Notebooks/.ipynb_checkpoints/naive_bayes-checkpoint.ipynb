# %%
import sklearn.datasets as ds
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
# %matplotlib inline

# %%
dados = pd.read_csv("../Csv/DadosProcessados.csv")

# %%
dict1 = {'Concludente': '1', 'Desistente':'0'}
simNao = {'Sim' : '1', 'Não' : '0'}
escolas = {'Privada' : '1', 'Pública' = '0'}
tipoEscola = {'Instituto Federal' : '1', 'Municipal/Estadual' : '0', 'Estudou em privada' : '-1'}

# %%
dados[dados.keys()[0]] = dados[dados.keys()[0]].apply(lambda x: x.replace(list(dict1.keys())[0], list(dict1.values())[0])

# %%
# Out:
#    Situação     Ingresso Semestre de Conclusão Experiência Prévia  \
# 0         1  2010 - 2012           2016 - 2018                Sim
# 1         1  2006 - 2008           2010 - 2012                Não
# 2         1  2010 - 2012           2016 - 2018                Não
# 3         1  2012 - 2014           2016 - 2018                Não
# 4         1  2010 - 2012           2016 - 2018                Sim
# 5         0  2012 - 2014           2016 - 2018                Sim
# 6         0  2012 - 2014           2012 - 2014                Sim
# 7         0  2016 - 2018                  2018                Sim
# 8         1  2006 - 2008           2010 - 2012                Sim
# 9         0  2012 - 2014           2012 - 2014                Sim
# 10        1  2006 - 2008           2010 - 2012                Não
# 11        1  2006 - 2008           2010 - 2012                Sim
# 12        1  2008 - 2010           2014 - 2016                Não
# ...
